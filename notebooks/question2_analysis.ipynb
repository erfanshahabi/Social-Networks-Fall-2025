# %%
import sys
sys.path.append('..')

from src.generative_models import (
    barabasi_albert_model,
    deterministic_scale_free_construction,
    plot_degree_distribution_comparison,
    visualize_networks,
    plot_adjacency_matrix,
    plot_sorted_adjacency_matrix,
    compare_blockiness,
    analyze_degree_distribution
)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 sys.path.append('..')
# ----> 4 from src.generative_models import (
#       5     barabasi_albert_model,
#       6     deterministic_scale_free_construction,
#       7     plot_degree_distribution_comparison,
#       8     visualize_networks,
#       9     plot_adjacency_matrix,
#      10     plot_sorted_adjacency_matrix,
#      11     compare_blockiness,
#      12     analyze_degree_distribution
#      13 )
#
# ImportError: cannot import name 'plot_adjacency_matrix' from 'src.generative_models' (/Users/erfan/Documents/University/Social Networks/SN_HW1_810103166/notebooks/../src/generative_models.py)

# %%
N = 100
m = 3
iterations = N - 3

G_BA = barabasi_albert_model(N, m)
G_det = deterministic_scale_free_construction(iterations)
